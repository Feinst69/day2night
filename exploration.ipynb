# %% [markdown]
# # Introduction
# Exploring the tar file

# %%
import tarfile

# %%
with tarfile.open("aligned_images.tar", "r") as tar:
    tar.list()
# Out:
# ?rwxrws--- chaoqian/hays_lab          0 2014-01-23 21:24:39 imageAlignedLD/
# ?rwxrws--- chaoqian/hays_lab          0 2014-01-03 21:39:54 imageAlignedLD/00000270/
# ?rw-rwx--- chaoqian/hays_lab     191551 2014-01-03 21:39:47 imageAlignedLD/00000270/1.jpg
# ?rw-rwx--- chaoqian/hays_lab     239612 2014-01-03 21:39:47 imageAlignedLD/00000270/102.jpg
# ?rw-rwx--- chaoqian/hays_lab     154344 2014-01-03 21:39:47 imageAlignedLD/00000270/103.jpg
# ?rw-rwx--- chaoqian/hays_lab     229888 2014-01-03 21:39:47 imageAlignedLD/00000270/108.jpg
# ?rw-rwx--- chaoqian/hays_lab     247937 2014-01-03 21:39:48 imageAlignedLD/00000270/11.jpg
# ?rw-rwx--- chaoqian/hays_lab     240356 2014-01-03 21:39:48 imageAlignedLD/00000270/110.jpg
# ?rw-rwx--- chaoqian/hays_lab     182373 2014-01-03 21:39:48 imageAlignedLD/00000270/111.jpg
# ?rw-rwx--- chaoqian/hays_lab     224703 2014-01-03 21:39:48 imageAlignedLD/00000270/112.jpg
# ...

# %%
import os
from PIL import Image

# %%
os.path.join(path, os.listdir(path)[0])
# Out:
# 'night2day/val'

# %%
path = "night2day"
for i in range(len(os.listdir(path))):
    print (os.listdir(path)[i], "contient: ", len(os.listdir(os.path.join(path, os.listdir(path)[i]))), "images")
# Out:
# val contient:  10 images
# train contient:  17823 images
# test contient:  2287 images

# %%
(os.path.join(path, os.listdir(path)[0]))
# Out:
# 'night2day/val'

# %%
for i in range(len(os.listdir(path))):
    print('Image from: ',os.listdir(path)[i] )
    img = Image.open(os.path.join(os.path.join(path, os.listdir(path)[i]), os.listdir(os.path.join(path, os.listdir(path)[i]))[2]))
    img.show()
# Out:
# Image from:  val
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256>
# Image from:  train
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256>
# Image from:  test
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256>

# %%
i = 0
img = Image.open(os.path.join(os.path.join(path, os.listdir(path)[i]), os.listdir(os.path.join(path, os.listdir(path)[i]))[2]))

# %%
img.size
# Out:
# (512, 256)
